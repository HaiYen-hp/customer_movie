# %%
from themoviedb import TMDb
import requests
from googletrans import Translator
import json
import pandas as pd

# %%
tmdb = TMDb(key="710d86a93f14fbb9e075cf6cddafb5f7")

# %%
url = "https://api.themoviedb.org/3/certification/movie/list"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MTBkODZhOTNmMTRmYmI5ZTA3NWNmNmNkZGFmYjVmNyIsInN1YiI6IjY1YjM4NTdiNWUxNGU1MDE2MjBjMmUxNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZJvLVheE1lJhFMYvxrwcrFZGamEdhmHqLvaKeShgEKQ"
}

# %%
response = requests.get(url, headers=headers)

# %%
data_dict = json.loads(response.text)

# %%
data_dict['certifications']['US']
# Out:
# [{'certification': 'R',
#   'meaning': 'Under 17 requires accompanying parent or adult guardian 21 or older. The parent/guardian is required to stay with the child under 17 through the entire movie, even if the parent gives the child/teenager permission to see the film alone. These films may contain strong profanity, graphic sexuality, nudity, strong violence, horror, gore, and strong drug use. A movie rated R for profanity often has more severe or frequent language than the PG-13 rating would permit. An R-rated movie may have more blood, gore, drug use, nudity, or graphic sexuality than a PG-13 movie would admit.',
#   'order': 4},
#  {'certification': 'PG',
#   'meaning': 'Some material may not be suitable for children under 10. These films may contain some mild language, crude/suggestive humor, scary moments and/or violence. No drug content is present. There are a few exceptions to this rule. A few racial insults may also be heard.',
#   'order': 2},
#  {'certification': 'NC-17',
# ...

# %%
data_dict['certifications']['VI']
# Out:
# [{'certification': 'G', 'meaning': 'All ages admitted.', 'order': 1},
#  {'certification': 'PG',
#   'meaning': 'Some material may not be suitable for children.',
#   'order': 2},
#  {'certification': 'PG-13',
#   'meaning': 'Some material may be inappropriate for children under 13.',
#   'order': 3},
#  {'certification': 'R',
#   'meaning': 'Under 17 requires accompanying parent or adult guardian.',
#   'order': 4},
#  {'certification': 'NC-17',
#   'meaning': 'No one 17 and under admitted.',
#   'order': 5},
#  {'certification': 'NR', 'meaning': '', 'order': 0}]

# %%
certification_us = pd.DataFrame(data_dict['certifications']['US'])

# %%
certification_us['country'] = 'United States of America'

# %%
certification_us
# Out:
#   certification                                            meaning  order  \
# 0             R  Under 17 requires accompanying parent or adult...      4
# 1            PG  Some material may not be suitable for children...      2
# 2         NC-17  These films contain excessive graphic violence...      5
# 3             G  All ages admitted. There is no content that wo...      1
# 4            NR                             No rating information.      0
# 5         PG-13  Some material may be inappropriate for childre...      3
#
#                     country
# 0  United States of America
# 1  United States of America
# 2  United States of America
# 3  United States of America
# 4  United States of America
# 5  United States of America

# %%
certification_vn = pd.DataFrame(data_dict['certifications']['VI'])

# %%
certification_vn['country'] = 'Vietnam'

# %%
certification = pd.concat([certification_us, certification_vn],ignore_index=True)

# %%
certification
# Out:
#    certification                                            meaning  order  \
# 0              R  Under 17 requires accompanying parent or adult...      4
# 1             PG  Some material may not be suitable for children...      2
# 2          NC-17  These films contain excessive graphic violence...      5
# 3              G  All ages admitted. There is no content that wo...      1
# 4             NR                             No rating information.      0
# 5          PG-13  Some material may be inappropriate for childre...      3
# 6              G                                 All ages admitted.      1
# 7             PG    Some material may not be suitable for children.      2
# 8          PG-13  Some material may be inappropriate for childre...      3
# 9              R  Under 17 requires accompanying parent or adult...      4
# 10         NC-17                      No one 17 and under admitted.      5
# ...

# %%
url2 = "https://api.themoviedb.org/3/certification/tv/list"

headers2 = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MTBkODZhOTNmMTRmYmI5ZTA3NWNmNmNkZGFmYjVmNyIsInN1YiI6IjY1YjM4NTdiNWUxNGU1MDE2MjBjMmUxNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZJvLVheE1lJhFMYvxrwcrFZGamEdhmHqLvaKeShgEKQ"
}

response2 = requests.get(url2, headers=headers2)

# %%
data_dict2 = json.loads(response2.text)

# %%
certification_tv_us = pd.DataFrame(data_dict2['certifications']['US'])

# %%
certification_tv_us
# Out:
#   certification                                            meaning  order
# 0         TV-MA  This program is specifically designed to be vi...      6
# 1          TV-Y  This program is designed to be appropriate for...      1
# 2         TV-14  This program contains some material that many ...      5
# 3            NR                             No rating information.      0
# 4         TV-PG  This program contains material that parents ma...      4
# 5         TV-Y7  This program is designed for children age 7 an...      2
# 6          TV-G  Most parents would find this program suitable ...      3

# %%
certification_tv_us['country'] = 'United States of America'

# %%
certification = pd.concat(
    [certification, certification_tv_us], ignore_index=True)

# %%
certification.fillna('No rating information.')
# Out:
#    certification                                            meaning  order  \
# 0              R  Under 17 requires accompanying parent or adult...      4
# 1             PG  Some material may not be suitable for children...      2
# 2          NC-17  These films contain excessive graphic violence...      5
# 3              G  All ages admitted. There is no content that wo...      1
# 4             NR                             No rating information.      0
# 5          PG-13  Some material may be inappropriate for childre...      3
# 6              G                                 All ages admitted.      1
# 7             PG    Some material may not be suitable for children.      2
# 8          PG-13  Some material may be inappropriate for childre...      3
# 9              R  Under 17 requires accompanying parent or adult...      4
# 10         NC-17                      No one 17 and under admitted.      5
# ...

# %%
translator = Translator()
for index, row in certification.iterrows():
    text = translator.translate(row['meaning'], dest='vi')
    certification.at[index, 'meaning_text'] = text.text

# %%
certification.to_excel('./dataset/meaning_of_rating.xlsx')
